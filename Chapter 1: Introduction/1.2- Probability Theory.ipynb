# %% [markdown]
# ## Probability Theory

# %% [markdown]
# Due of uncertaininty in the world, we are talking about probability now.  The cause of uncertaininty are numerous ranging from noises to teh limited data sizes. Probanility Theory helps us by providing a consistent framework for the qualification and manipulation of the uncertainity and helps us get the foundation of pattern recognition.
#
# There are two fundamental rules of probability theory viz;
#
# - Sum rule
# - Product rule

# %% [markdown]
# ## Sum Rule
# To understand the sum rule, we will start with an example from Khan Academy.
#
# Suppose we have a bag with
# - 8 Green Cubes
# - 9 Green Spheres
# - 5 Yellow Cubes
# - 7 Yellow Spheres
#
# So, what is the probability of getting cube of any color, $\text{P(Cube of any color)}$? Before answering the question let's ponder on few things. There are altogether 29 objects in the bag and out of which 13 are the cubes. Let's see in the graph below:
#
#
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=12OeiW-vDqixDWCD6QhBEZYKhfZoioFHI" alt="sigmoid_graph" height="225" width="350">
# </center>
#
#
# So, considering that each outcome form the bag is equally likeable(we assume this unless mentioned), the proabbility of getting cube of any color from the bag is:
#
# $$\text{P(Cube of any color)} = \frac{\text{Total number of cubes}}{\text{Total number of items in the bag}} = \frac{13}{29}$$
#
# Smilarly, let's find out the probability of popping out yellow item from the bag. There are altogether 12 items in the bag, comprising 5 yellow cubes and 7 yellow spheres. In diagram:
#
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1i0qXDA4AIgU58gIG0NXN8I_YUL7yJsYk" alt="sigmoid_graph" height="225" width="350">
# </center>
#
# Again, considering the each item from the bag eqaully probable to pop out, the probability of getting yellow item is:
# $$\text{P(Yellow Item)} = \frac{\text{Total number of Yellow items}}{\text{Total number of items in the bag}} = \frac{12}{29}$$
#
# So, what is the probabiliy of getting yellow cube? Well, we have 29 equal possibilities and hence, the probability of getting yellow cube is:
#
# $$\text{P(Yellow Cube)} =  \frac{5}{29}$$
#
# So, thing thing can be easily verified and visualised through venn diagram. The intersection portion of the diagram comprises of the 5 yellow cubes, i.e., both cubes and yellows. In diagram:
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1Y-dF90F_Dk6kx7rD0i8bJGB44iHMicTQ" alt="sigmoid_graph" height="225" width="350">
# </center>
#
# Now that we are warmed up with some of the basic probability values, it is the right time to ask a question, What is the probability of getting yellow item or cube of any color? In notation:
#
# $$\text{P(Yellow item or Cube of any color)} = ?$$
#
# Now, we will take a help from the venn diagram. The denominator is 29, for sure, since there are total items as 29 and they are equally likely to pop put. For the numerator part, we need to encounter both yellow item and cubes. So, the total yellow items are 12 and total 13 cubes. But remember that while considering 12 yellow items, we have already taken 5 yellow cubes into account, which is given by the intersection section of the venn diagram. Hence,
#
# $$\text{P(Yellow item or Cube of any color)} = \frac{\text{(Number of yellow items) + (Number of cubes) - (Number of yellow cubes)}}{29} = \frac{12 + 13 -5}{29}$$
#
# So, we removed the hidden 5 yellow cubes under the yellow items because we have already taken total cubes into account. Now, we can replace these above numbers in probability terms as:
#
# $$\text{P(Yellow item or Cube of any color)} = \frac{12}{29} + \frac{13}{29} - \frac{5}{29}$$
# $$\text{P(Yellow item or Cube of any color)} = \text{P(Yellow Item)} + \text{P(Cube of any color)} - \text{P(Yellow Cube)}$$
#
#
# In General,
#
# $$\text{P(A or B)} = \text{P(A)} + \text{P(B)} - \text{P(A and B)}$$
#
# This is called the Addition rule.
# We can't just add two probabilies, because they might have some overlapping and we have to encounter then ny subtraction. In case, if we don;t have an overlap as in the diagram below, the intersection would be 0 and this would be simply adding the probabilities, i.e.,
#
# $$\text{P(A or B)} = \text{P(A)} + \text{P(B) since, P(A and B) = 0}$$
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1joMGFmxp8iwT-FjuJbEGexN00EjfCeNy" alt="sigmoid_graph" height="225" width="350">
# </center>
# In addition, such events are called mututally exclusive, since they event A and event B can't happen at the same time.
# Ocuurance of event A implies the non occurance of event B.

# %% [markdown]
# Now, we will see another fundamental rule of the probability, Product Rule.
#
# ## Product Rule
#
# For the product rule, we will start with the formulaes and then interpret it's meaning. But first, we will talk about the two types of events:
#
# - Independent Events
# - Dependent Events
#
# Probability is all about determinig the likelihood of the events.
#
# __Independent Events__
#
# Two or more events are called independent if the occurance of one event doesn't effect the occurance of any other events. For example: probability of getting one on a first roll and then three in a second roll in a normal six sided dice, because the both events are independent of each other and has the probability of $\frac{1}{6}$.
#
# __Dependent Events__
#
# Two or more events are called dependednt if the occurance of an event affects the occurance of other events. For example: probability of getting an Ace in drawing first card from a deck of the 52 cards and then getting an King in drawing second card from the remaining 51 cards.
#
# These events are dependent because drawing an Ace changes the probability of getting King on the second place, since the sample spaces dedcrease from 52 to 51.
#
# So, now we know defination of Independednt events and dependent events, let's proceed to the product rule. We have product rule for both independent and dependent events.
#
# A question to start; What is the probability of rolling three and then one on a normal six sided dice?
# Since, these are an independent events, we will use the product rule for independent events, i.e.,
#
# $$\text{P(getting three on first roll and getting one on second roll)} = \text{P(getting three on first roll)}* \text{P(getting one on the second roll)}$$
#
# $$\text{P(getting three on first roll and getting one on second roll)} = \frac{1}{6}*\frac{1}{6} = \frac{1}{36}$$
#
# Generally for the two independent events, $A$ and $B$, the multiplication(Product rule, AND rule) states:
#
# $$P(A$$
